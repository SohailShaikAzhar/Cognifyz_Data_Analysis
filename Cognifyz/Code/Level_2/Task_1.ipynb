# %% [markdown]
# # Task: Restaurant Ratings

# %% [markdown]
# ### Analyze the distribution of aggregate ratings and determine the most common rating range.

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv("Dataset.csv")
df = df.dropna(subset=['Aggregate rating'])
df = df[df["Aggregate rating"] > 0]
ratings = df["Aggregate rating"]

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(11, 5))
sns.countplot(x=df['Aggregate rating'], palette="viridis")

plt.xlabel("Aggregate Rating")
plt.ylabel("Number of Restaurants")
plt.title("Count of Restaurants for Each Rating")

plt.show()

# %%
most_common_rating = rating_counts.idxmax()
most_common_count = rating_counts.max()
print(f"The most common rating is {most_common_rating} with {most_common_count} restaurants.")
# Out:
# The most common rating is 3-4 with 4388 restaurants.

# %% [markdown]
# ###  Calculate the average number of votes received by restaurants.

# %%
average_votes = df["Votes"].mean()

print(f"Average number of votes received by restaurants: {average_votes:.2f}")
# Out:
# Average number of votes received by restaurants: 202.19
